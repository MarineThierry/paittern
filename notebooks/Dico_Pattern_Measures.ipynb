# %%
{'Aaron': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Waist to hips'],
 'Albert': ['Chest circumference',
  'HPS to waist back',
  'Hips circumference',
  'Waist circumference',
  'Waist to knee'],
 'Bee': ['Bust point to underbust',
  'Bust span',
  'Chest circumference',
  'HPS to bust',
  'HPS to waist back',
  'HPS to waist front',
  'High bust',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Underbust',
  'Waist back',
  'Waist circumference'],
 'Bella': ['Bust span',
  'Chest circumference',
  'HPS to bust',
  'HPS to waist back',
  'HPS to waist front',
  'High bust',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Underbust',
  'Waist back',
  'Waist circumference'],
 'Benjamin': ['Neck circumference'],
 'Bent': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to elbow',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist to hips',
  'Wrist circumference'],
 'Breanna': ['Biceps circumference',
  'Bust front',
  'Bust span',
  'HPS to bust',
  'HPS to waist back',
  'HPS to waist front',
  'High bust',
  'High bust front',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist circumference',
  'Waist to hips',
  'Wrist circumference'],
 'Brian': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist to hips',
  'Wrist circumference'],
 'Bruce': ['Hips circumference',
  'Upper leg circumference',
  'Waist to hips',
  'Waist to upper leg'],
 'Carlita': ['Biceps circumference',
  'Bust span',
  'Chest circumference',
  'HPS to bust',
  'HPS to waist back',
  'High bust',
  'Hips circumference',
  'Neck circumference',
  'Seat circumference',
  'Shoulder slope',
  'Shoulder to elbow',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist circumference',
  'Waist to floor',
  'Waist to hips',
  'Waist to seat',
  'Wrist circumference'],
 'Carlton': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Hips circumference',
  'Neck circumference',
  'Seat circumference',
  'Shoulder slope',
  'Shoulder to elbow',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist circumference',
  'Waist to floor',
  'Waist to hips',
  'Waist to seat',
  'Wrist circumference'],
 'Cathrin': ['Hips circumference',
  'Underbust',
  'Waist circumference',
  'Waist to hips',
  'Waist to underbust'],
 'Charlie': ['Cross seam',
  'Cross seam front',
  'Knee circumference',
  'Seat back',
  'Seat circumference',
  'Waist back',
  'Waist circumference',
  'Waist to floor',
  'Waist to hips',
  'Waist to knee',
  'Waist to seat',
  'Waist to upper leg'],
 'Cornelius': ['Hips circumference',
  'Inseam',
  'Knee circumference',
  'Seat circumference',
  'Waist circumference',
  'Waist to floor',
  'Waist to hips',
  'Waist to knee'],
 'Diana': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist circumference',
  'Waist to hips',
  'Wrist circumference'],
 'Florence': ['Head circumference'],
 'Florent': ['Head circumference'],
 'Holmes': ['Head circumference'],
 'Hortensia': [],
 'Huey': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Head circumference',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist to hips',
  'Wrist circumference'],
 'Hugo': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Head circumference',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist to hips',
  'Wrist circumference'],
 'Jaeger': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to elbow',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist circumference',
  'Waist to hips',
  'Wrist circumference'],
 'Lunetius': ['HPS to waist back',
  'Neck circumference',
  'Shoulder to elbow',
  'Shoulder to shoulder',
  'Waist to floor',
  'Waist to hips',
  'Waist to knee',
  'Waist to upper leg'],
 'Paco': ['Cross seam',
  'Cross seam front',
  'Heel circumference',
  'Knee circumference',
  'Seat back',
  'Seat circumference',
  'Waist back',
  'Waist circumference',
  'Waist to floor',
  'Waist to hips',
  'Waist to knee',
  'Waist to seat',
  'Waist to upper leg'],
 'Penelope': ['Seat circumference',
  'Waist circumference',
  'Waist to hips',
  'Waist to knee',
  'Waist to seat'],
 'Sandy': ['Hips circumference',
  'Waist circumference',
  'Waist to floor',
  'Waist to hips'],
 'Shin': ['Hips circumference',
  'Upper leg circumference',
  'Waist to hips',
  'Waist to upper leg'],
 'Simon': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist circumference',
  'Waist to hips',
  'Wrist circumference'],
 'Simone': ['Biceps circumference',
  'Bust span',
  'Chest circumference',
  'HPS to bust',
  'HPS to waist back',
  'High bust',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist circumference',
  'Waist to hips',
  'Wrist circumference'],
 'Sven': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist circumference',
  'Waist to hips',
  'Wrist circumference'],
 'Tamiko': ['Chest circumference',
  'HPS to waist back',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Waist to hips'],
 'Teagan': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Waist circumference',
  'Waist to hips'],
 'Theo': ['Crotch depth',
  'Hips circumference',
  'Inseam',
  'Knee circumference',
  'Seat circumference',
  'Waist to hips'],
 'Tiberius': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Head circumference',
  'Hips circumference',
  'Seat circumference',
  'Shoulder to elbow',
  'Shoulder to shoulder',
  'Waist circumference',
  'Waist to floor',
  'Waist to knee',
  'Waist to upper leg'],
 'Titan': ['Cross seam',
  'Cross seam front',
  'Knee circumference',
  'Seat back',
  'Seat circumference',
  'Waist back',
  'Waist circumference',
  'Waist to floor',
  'Waist to hips',
  'Waist to knee',
  'Waist to seat',
  'Waist to upper leg'],
 'Trayvon': ['HPS to waist back', 'Neck circumference', 'Waist to hips'],
 'Ursula': ['Seat circumference',
  'Waist circumference',
  'Waist to seat',
  'Waist to upper leg'],
 'Wahid': ['Biceps circumference',
  'Chest circumference',
  'HPS to waist back',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Waist circumference',
  'Waist to hips'],
 'Walburga': ['HPS to waist back',
  'Head circumference',
  'Neck circumference',
  'Shoulder to shoulder',
  'Waist to floor',
  'Waist to hips',
  'Waist to knee',
  'Waist to upper leg'],
 'Waralee': ['Crotch depth', 'Inseam', 'Seat circumference', 'Waist to hips'],
 'Yuri': ['Biceps circumference',
  'Chest circumference',
  'HPS to bust',
  'HPS to waist back',
  'Head circumference',
  'Hips circumference',
  'Neck circumference',
  'Shoulder slope',
  'Shoulder to shoulder',
  'Shoulder to wrist',
  'Waist to hips',
  'Wrist circumference']}
